# %%
#import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
students_needed = pd.read_csv("data/students_needed.csv")

# %%
students_needed
# Out:
#     year                     study_field                         degree  \
# 0   2021                      Informatik               Informatik_total
# 1   2021                      Informatik               Informatik_males
# 2   2021                      Informatik             Informatik_females
# 3   2021                      Informatik                       Bachelor
# 4   2021                      Informatik                       Bachelor
# 5   2021                      Informatik                       Bachelor
# 6   2021                      Informatik                         Master
# 7   2021                      Informatik                         Master
# 8   2021                      Informatik                         Master
# 9   2021                      Informatik                            PhD
# 10  2021                      Informatik                            PhD
# 11  2021                      Informatik                            PhD
# ...

# %%
for number, level, degree, study_field in students_needed:
    for tot in degree:
        if study_field == 'Informatik':
            percentage_bsc = ()

# %%
# filter the DataFrame to get total_informatik and bachelor rows in Informatik field
info_bs = students_needed.loc[(students_needed['degree'].isin(['Informatik_total', 'Bachelor'])) & (students_needed['study_field'] == 'Informatik')]

# calculate the percentage of bachelor students in informatik out of total_informatik
percentage_bs = (info_bs.loc[info_bs['degree'] == 'Bachelor', 'number'].values[0] / info_bs.loc[info_bs['degree'] == 'Informatik_total', 'number'].values[0]) * 100

percentage_bs
# Out:
# 53.771135456905824

# %%
# filter the DataFrame to get total_informatik and bachelor rows in Informatik field
info_ms = students_needed.loc[(students_needed['degree'].isin(['Informatik_total', 'Master'])) & (students_needed['study_field'] == 'Informatik')]

# calculate the percentage of bachelor students in informatik out of total_informatik
percentage_ms = (info_ms.loc[info_ms['degree'] == 'Master', 'number'].values[0] / info_ms.loc[info_ms['degree'] == 'Informatik_total', 'number'].values[0]) * 100

percentage_ms
# Out:
# 39.35152935216262

# %%
# filter the DataFrame to get total_informatik and bachelor rows in Informatik field
info_phd = students_needed.loc[(students_needed['degree'].isin(['Informatik_total', 'PhD'])) & (students_needed['study_field'] == 'Informatik')]

# calculate the percentage of bachelor students in informatik out of total_informatik
percentage_phd = (info_phd.loc[info_phd['degree'] == 'PhD', 'number'].values[0] / info_phd.loc[info_phd['degree'] == 'Informatik_total', 'number'].values[0]) * 100

percentage_phd
# Out:
# 5.161167753783801

# %%
# filter the DataFrame to get total_Elektrotechnik/Elektronik and bachelor rows in Elektrotechnik/Elektronik field
elektro_bs = students_needed.loc[(students_needed['degree'].isin(['Elektrotechnik_total', 'Bachelor'])) & (students_needed['study_field'] == 'Elektrotechnik/Elektronik')]

# calculate the percentage of bachelor students in informatik out of total_informatik
percentage_bse = (elektro_bs.loc[elektro_bs['degree'] == 'Bachelor', 'number'].values[0] / elektro_bs.loc[elektro_bs['degree'] == 'Elektrotechnik_total', 'number'].values[0]) * 100

percentage_bse
# Out:
# 50.06485084306096

# %%
# filter the DataFrame to get total_Elektrotechnik/Elektronik and bachelor rows in Elektrotechnik/Elektronik field
elektro_ms = students_needed.loc[(students_needed['degree'].isin(['Elektrotechnik_total', 'Master'])) & (students_needed['study_field'] == 'Elektrotechnik/Elektronik')]

# calculate the percentage of bachelor students in informatik out of total_informatik
percentage_mse = (elektro_ms.loc[elektro_ms['degree'] == 'Master', 'number'].values[0] / elektro_ms.loc[elektro_ms['degree'] == 'Elektrotechnik_total', 'number'].values[0]) * 100

percentage_mse
# Out:
# 39.79247730220493

# %%
# filter the DataFrame to get total_Elektrotechnik/Elektronik and bachelor rows in Elektrotechnik/Elektronik field
elektro_phd = students_needed.loc[(students_needed['degree'].isin(['Elektrotechnik_total', 'PhD'])) & (students_needed['study_field'] == 'Elektrotechnik/Elektronik')]

# calculate the percentage of bachelor students in informatik out of total_informatik
percentage_phde = (elektro_phd.loc[elektro_phd['degree'] == 'PhD', 'number'].values[0] / elektro_phd.loc[elektro_phd['degree'] == 'Elektrotechnik_total', 'number'].values[0]) * 100

percentage_phde
# Out:
# 6.658019887591872

# %%
students_needed['degree'] = students_needed['degree'].replace('Bauingenieur_total', 'Bachelor')
students_needed['degree'] = students_needed['degree'].replace('Bauingenieur_males', 'Bachelor')
students_needed['degree'] = students_needed['degree'].replace('Bauingenieur_females', 'Bachelor')
students_needed['degree'] = students_needed['degree'].replace('Total', 'Bauingenieur_total')

# %%
students_needed
# Out:
#     year                     study_field                         degree  \
# 0   2021                      Informatik               Informatik_total
# 1   2021                      Informatik               Informatik_males
# 2   2021                      Informatik             Informatik_females
# 3   2021                      Informatik                       Bachelor
# 4   2021                      Informatik                       Bachelor
# 5   2021                      Informatik                       Bachelor
# 6   2021                      Informatik                         Master
# 7   2021                      Informatik                         Master
# 8   2021                      Informatik                         Master
# 9   2021                      Informatik                            PhD
# 10  2021                      Informatik                            PhD
# 11  2021                      Informatik                            PhD
# ...

# %%
# filter the DataFrame to get total_Elektrotechnik/Elektronik and bachelor rows in Elektrotechnik/Elektronik field
bau_bs = students_needed.loc[(students_needed['degree'].isin(['Bauingenieur_total', 'Bachelor'])) & (students_needed['study_field'] == 'Bauingenieurwesen/Ingenieurbau') & (students_needed['gender'] == 'Total_gender')]

# calculate the percentage of bachelor students in informatik out of total_informatik
percentage_bsb = (bau_bs.loc[bau_bs['degree'] == 'Bachelor', 'number'].values[0] / bau_bs.loc[bau_bs['degree'] == 'Bauingenieur_total', 'number'].values[0]) * 100

percentage_bsb
# Out:
# 54.168348809043195

# %%
# filter the DataFrame to get total_Elektrotechnik/Elektronik and bachelor rows in Elektrotechnik/Elektronik field
bau_ms = students_needed.loc[(students_needed['degree'].isin(['Bauingenieur_total', 'Master'])) & (students_needed['study_field'] == 'Bauingenieurwesen/Ingenieurbau') & (students_needed['gender'] == 'Total_gender')]

# calculate the percentage of bachelor students in informatik out of total_informatik
percentage_msb = (bau_ms.loc[bau_ms['degree'] == 'Master', 'number'].values[0] / bau_ms.loc[bau_ms['degree'] == 'Bauingenieur_total', 'number'].values[0]) * 100

percentage_msb
# Out:
# 38.231731933790876

# %%
# filter the DataFrame to get total_Elektrotechnik/Elektronik and bachelor rows in Elektrotechnik/Elektronik field
bau_phd = students_needed.loc[(students_needed['degree'].isin(['Bauingenieur_total', 'PhD'])) & (students_needed['study_field'] == 'Bauingenieurwesen/Ingenieurbau') & (students_needed['gender'] == 'Total_gender')]

# calculate the percentage of bachelor students in informatik out of total_informatik
percentage_phdb = (bau_phd.loc[bau_phd['degree'] == 'PhD', 'number'].values[0] / bau_phd.loc[bau_phd['degree'] == 'Bauingenieur_total', 'number'].values[0]) * 100

percentage_phdb
# Out:
# 3.4012918853451755
